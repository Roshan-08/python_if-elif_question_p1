# %%
'''Q2. Write a program to accept percentage from the user and display
the grade according to the following criteria:

Marks Grade
> 90 A
> 80 and <= 90 B
>= 60 and <= 80 C
below 60 D'''

marks =int(input('Enter the percentage:'))


if  marks>90 :
    print("A")

elif  marks<=90 and marks>80 :
    print('B')

elif  marks<=80 and marks>=60 :
    print('C')

else   :
    print('D')
# Out:
# Enter the percentage: 65
# C

# %%
# Q3. Accept the age of 4 people and display the youngest one?

Sachin = int(input("Enter Sachin age : "))
Ram = int(input("Enter Ram age : "))
Mohan = int(input("Enter Mohan age : "))
Vicky = int(input("Enter Vicky age : "))

youngest = Sachin

if Ram < youngest:
    youngest = Ram
if Mohan < youngest:
    youngest = Mohan
if Vicky < youngest:
    youngest = Vicky

print("The youngest age is:", youngest)
# Out:
# Enter Sachin age :  5
# Enter Ram age :  4
# Enter Mohan age :  3
# Enter Vicky age :  7
# The youngest age is: 3

# %%
# Q3. Accept the age of 4 people and display the youngest one?

name1 =input('Enter the name1 :')
age1 = int(input('Enter the age1 :'))

name2 =input('Enter the name2 :')
age2 = int(input('Enter the age2 :'))

name3 =input('Enter the name3 :')
age3 = int(input('Enter the age3 :'))

name4 =input('Enter the name4 :')
age4 = int(input('Enter the age4 :'))

youngest_name = name1
youngest_age= age1

if age2 < youngest_age:
    youngest_name, youngest_age = name2, age2
if age3 < youngest_age:
    youngest_name, youngest_age = name3, age3
if age4 < youngest_age:
    youngest_name, youngest_age = name4, age4

    print("youngest person is:", youngest_name)
    print("Age is:", youngest_age)
# Out:
# Enter the name1 : Suman
# Enter the age1 : 22
# Enter the name2 : Aniket
# Enter the age2 : 24
# Enter the name3 : Eshan
# Enter the age3 : 23
# Enter the name4 : Mohit
# Enter the age4 : 21
# youngest person is: Mohit
# Age is: 21

# %%
'''Q4. A company decided to give bonus to employee
according to following criteria:

Time period of Service Bonus
More than 10 years 10%
>=6 and <=10 8%
Less than 6 years 5%

Ask user for their salary and years of service and print the
net bonus amount?'''

salary = int(input("Enter the salary of emp: "))
year_of_service = int(input("Enter the Years of service of emp: "))

if year_of_service > 10:
    bonus = salary * 0.10

elif year_of_service >= 6:
    bonus = salary * 0.08

elif year_of_service > 0:
    bonus = salary * 0.05

else:
    bonus = 0

print("Bonus of the Employee:", bonus)
# Out:
# Enter the salary of emp1:  45000
# Enter the Years of service of emp1:  7
# Bonus of the Employee: 3600.0

# %%
n = int(input("Enter number of employees: "))

for i in range(n):
    print(f"\nEmployee {i+1}")
    
    name = input("Enter name: ")
    salary = int(input("Enter salary: "))
    years = int(input("Enter years of service: "))
    
    if years > 10:
        bonus = salary * 0.10
    elif years >= 6:
        bonus = salary * 0.08
    elif years > 0:
        bonus = salary * 0.05
    else:
        bonus = 0
    
    print(f"{name}'s Bonus: {bonus}")
# Out:
# Enter number of employees:  3
# Employee 1
# Enter name:  Amit
# Enter salary:  43000
# Enter years of service:  4
# Amit's Bonus: 2150.0
#
# Employee 2
# Enter name:  Eshan
# Enter salary:  56000
# Enter years of service:  8
# Eshan's Bonus: 4480.0
#
# Employee 3
# Enter name:  Aniket
# Enter salary:  44000
# Enter years of service:  11
# Aniket's Bonus: 4400.0

# %%
# Q5. Accept three numbers from the user and display the second largest number?

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if (a > b and a < c) or (a < b and a > c):
    second = a
elif (b > a and b < c) or (b < a and b > c):
    second = b
else:
    second = c

print("Second largest number is:", second)
# Out:
# Enter first number:  3
# Enter second number:  7
# Enter third number:  5
# Second largest number is: 5

# %%
nums = []

for i in range(3):
    n = int(input(f"Enter number {i+1}: "))
    nums.append(n)

nums.sort()

print("Second largest number is:", nums[1])
# Out:
# Enter number 1:  -4
# Enter number 2:  -2
# Enter number 3:  -5
# Second largest number is: -4

# %%
'''Q6. Accept the marked price from the user and calculate
the Net amount as (Marked Price – Discount) to pay
according to following criteria:

Marked Price Discount
>10000 20%
>7000 and <=10000 15%
<=7000 10%'''

n = int(input("Enter number of product: "))

for i in range(n):
    print(f"\nproduct {i+1}")
    
    product_name = input("Enter name: ")
    marked_price = int(input("Enter marked price: "))
   # years = int(input("Enter years of service: "))
    
    if marked_price > 100000:
        discount = marked_price * 0.20
    elif 100000>= marked_price > 70000:
        discount = marked_price * 0.15
    elif marked_price <= 70000:
        discount = marked_price * 0.10
    else:
        discount = 0
    
    print(f"{product_name}'s discount: {discount}")
# Out:
# Enter number of product:  3
# product 1
# Enter name:  iphone
# Enter marked price:  133800
# iphone's discount: 26760.0
#
# product 2
# Enter name:  laptop
# Enter marked price:  89700
# laptop's discount: 13455.0
#
# product 3
# Enter name:  tab
# Enter marked price:  67300
# tab's discount: 6730.0

# %%
Q7. Accept the marks of English, Math and Science,
Social Studies Subject and display the stream allotted
according to following:

All Subjects more than 80 marks — Science Stream

English >80 and Math, Science above 50 — Commerce Stream

English > 80 and social studies > 80 — Humanities
