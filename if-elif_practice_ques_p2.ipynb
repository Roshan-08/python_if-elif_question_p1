# %%
'''Q7. Accept the marks of English, Math and Science,
Social Studies Subject and display the stream allotted
according to following:

All Subjects more than 80 marks — Science Stream
English >80 and Math, Science above 50 — Commerce Stream
English > 80 and social studies > 80 — Humanities'''

Eng_marks = float(input("Enter Eng_marks:"))
Maths_marks = float(input("Enter Maths_marks:"))
Science_marks = float(input("Enter Science_marks:"))
SST_marks = float(input("Enter SST_marks:"))

if Eng_marks >80 and Maths_marks >80 and Science_marks >80 and SST_marks >80:
    print("Science Stream")
elif Eng_marks >80 and Maths_marks >50 and Science_marks >50:
    print("Commerce Stream")
elif Eng_marks >80 and SST_marks > 80:
    print("Humanities")
else:
    print("No stream allotted")
# Out:
# Enter Eng_marks: 84
# Enter Maths_marks: 55
# Enter Science_marks: 64
# Enter SST_marks: 82
# Commerce Stream

# %%
# Q8. Write a program to display "Hello" if a number entered by user is a multiple of five, otherwise print "Bye"?

number = int(input("Enter your number:"))

if number % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Enter your number: 554
# Bye

# %%
# Q9. Write a program to check whether the last digit of a number (entered by user) is divisible by 3 or not?

number = int(input("Enter your number:"))

last_digit = number % 10

if last_digit % 3 == 0:
    print("Yes, it is divisible:")
else:
    print("Not devisible:")
# Out:
# Enter your number: 65
# Not devisible:

# %%
# Q10. Write a program to check whether a number entered is three-digit number or not?

num = int(input("Enter a number: "))

if 100 <= abs(num) <= 999:
    print("It is a three-digit number")
else:
    print("It is NOT a three-digit number")
# Out:
# Enter a number:  -999
# It is a three-digit number

# %%
'''Q1. Write a program to calculate the electricity bill
using only if statement? (accept number of unit from user)
according to the following criteria:

Unit Price
First 100 units no charge
Next 100 units Rs 5 per unit
After 200 units Rs 10 per unit
(For example, if input unit is 350 than total bill amount is Rs2000). Lets explain...
For first 100 no charges
Now you have 250 unit remaining
100-200 you need to pay – 100*5 = 500
Now 200-100 you need to pay 150*10 = 1500
Total = 500+1500 = 2000'''

unit = int(input("Enter the unit used:"))

if unit <= 100:
    bill = unit *0
elif 100 <unit <=200:
    bill = (unit -100)*5
else:
    bill = (unit-200)*10 + 100*5
    
print(f"Your Electricity bill is: ₹{bill}")
# Out:
# Enter the unit used: 150
# Your Electricity bill is: ₹250
